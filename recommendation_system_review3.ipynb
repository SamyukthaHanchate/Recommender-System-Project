# %%
#importing the libraries and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import re
import nltk
from nltk import pos_tag, word_tokenize, PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
wordnet_lemmatizr=WordNetLemmatizer()
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# AMAZON WEBSITE

# %%
df = pd.read_csv('/content/drive/MyDrive/product.csv')

print("Shape: %s" % str(df.shape))
print("Column names: %s" % str(df.columns))

df.head()
# Out:
# Shape: (11346, 12)
# Column names: Index(['Unnamed: 0', 'asin', 'avg.rating', 'avg.helpful.ratio', 'also_bought',
#        'also_viewed', 'brand', 'categories', 'description', 'price',
#        'salesRank', 'title'],
#       dtype='object')
#    Unnamed: 0        asin  avg.rating  avg.helpful.ratio  \
# 0           1  7806397051        2.50                NaN
# 1           2  9759091062        3.09                NaN
# 2           3  9788072216        5.00                NaN
# 3           4  9790790961        4.60                NaN
# 4           5  9790794231        4.50                NaN
#
#                                          also_bought  \
# 0  ['B00KR26VFE', 'B00E7LQHZ0', 'B00BMW24TU', 'B0...
# 1  ['B0054GLD1U', 'B003BRZCUC', 'B0054GBXOW', 'B0...
# 2  ['B006C5OHSI', 'B006P14842', 'B0072CSVB4', 'B0...
# 3  ['B007P7OPQQ', 'B0017JT658', 'B0084HM1DA', 'B0...
# 4  ['B0019M21OQ', 'B000E7YM8K', 'B0006V31FY', 'B0...
#
#                                          also_viewed         brand  \
# 0  ['B008GOR6O0', 'B00EOFEKF8', 'B00IIFVJZ4', 'B0...          COKA
# 1  ['B0054GBXOW', 'B0054GLD1U', 'B006VDOPPQ', 'B0...  Xtreme Brite
# 2  ['B0072CSVB4', 'B005YWBOHW', 'B00CGOUL2A', 'B0...         Prada
# 3  ['B005M2AQRI', 'B000VOHKK8', 'B0017JT658', 'B0...       Versace
# 4  ['B000E7YM8K', 'B0019M21OQ', 'B0006V31FY', 'B0...
#
#                                           categories  \
# 0  [['Beauty', 'Makeup', 'Face', 'Concealers & Ne...
# 1  [['Beauty', 'Hair Care', 'Styling Products', '...
# 2  [['Beauty', 'Fragrance', "Women's", 'Eau de Pa...
# 3  [['Beauty', 'Fragrance', "Women's", 'Eau de To...
# 4  [['Beauty', 'Fragrance', "Women's", 'Eau de Pa...
#
#                                          description  price  \
# 0  An extensive range of 15 multiple vibrant long...   5.04
# 1  Xtreme Brite  Brightening gel is a highly conc...  19.99
# 2  Prada Candy By Prada Eau De Parfum Spray 1.7 O...  65.86
# 3  Versace Bright Crystal Perfume for Women 3 oz ...  52.33
# 4  STELLA For Women By STELLA MCCARTNEY 1.7 oz ED...    NaN
#
#             salesRank                                              title
# 0   {'Beauty': 10486}  WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 1   {'Beauty': 52254}                  Xtreme Brite Brightening Gel 1oz.
# 2   {'Beauty': 78916}  Prada Candy By Prada Eau De Parfum Spray 1.7 O...
# 3     {'Beauty': 764}  Versace Bright Crystal Eau de Toilette Spray f...
# 4  {'Beauty': 142503}                            Stella McCartney Stella

# %%
# Rating frequency
sns.set(rc={'figure.figsize': (11.7, 8.27)})
sns.set_style('whitegrid')
ax = sns.countplot(x='avg.rating', data=df, palette=sns.color_palette('Greys'))
ax.set(xlabel='Rating', ylabel='Count')
plt.show()

# %%
df.shape
# Out:
# (11346, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# asin                     0
# avg.rating               0
# avg.helpful.ratio    10554
# also_bought              0
# also_viewed              0
# brand                   16
# categories               0
# description            682
# price                  405
# salesRank                0
# title                    0
# dtype: int64

# %%
df=df.drop(labels='categories', axis=1)
df=df.drop(labels='avg.helpful.ratio', axis=1)
df=df.drop(labels='brand', axis=1)
df=df.drop(labels='description', axis=1)
df=df.drop(labels='title', axis=1)
df=df.drop(labels='Unnamed: 0', axis=1)
df
# Out:
#              asin  avg.rating  \
# 0      7806397051        2.50
# 1      9759091062        3.09
# 2      9788072216        5.00
# 3      9790790961        4.60
# 4      9790794231        4.50
# ...           ...         ...
# 11341  B00L5KTZ0K        5.00
# 11342  B00L6Q3BH6        4.75
# 11343  B00LCEROA2        5.00
# 11344  B00LG63DOM        4.80
# 11345  B00LLPT4HI        5.00
#
#                                              also_bought  \
# 0      ['B00KR26VFE', 'B00E7LQHZ0', 'B00BMW24TU', 'B0...
# 1      ['B0054GLD1U', 'B003BRZCUC', 'B0054GBXOW', 'B0...
# 2      ['B006C5OHSI', 'B006P14842', 'B0072CSVB4', 'B0...
# 3      ['B007P7OPQQ', 'B0017JT658', 'B0084HM1DA', 'B0...
# 4      ['B0019M21OQ', 'B000E7YM8K', 'B0006V31FY', 'B0...
# ...                                                  ...
# 11341  ['B00JJOEV9Y', 'B00LSXYC6G', 'B00KWP8ZIM', 'B0...
# 11342  ['B00JH29K6M', 'B00JH2B182', 'B004W4P7AI', 'B0...
# 11343  ['B00LNVW1IE', 'B00JYKGFWY', 'B00ELN94GS', 'B0...
# 11344  ['B00JJOEV9Y', 'B00KWP8ZIM', 'B00LDGV15I', 'B0...
# 11345  ['B00LFPS0CY', 'B00KZNOHTW', 'B00KQVTX06', 'B0...
#
#                                              also_viewed  price  \
# 0      ['B008GOR6O0', 'B00EOFEKF8', 'B00IIFVJZ4', 'B0...   5.04
# 1      ['B0054GBXOW', 'B0054GLD1U', 'B006VDOPPQ', 'B0...  19.99
# 2      ['B0072CSVB4', 'B005YWBOHW', 'B00CGOUL2A', 'B0...  65.86
# 3      ['B005M2AQRI', 'B000VOHKK8', 'B0017JT658', 'B0...  52.33
# 4      ['B000E7YM8K', 'B0019M21OQ', 'B0006V31FY', 'B0...    NaN
# ...                                                  ...    ...
# 11341  ['B00L8HA5L8', 'B00L2NX8YE', 'B00L8FDIZU', 'B0...  18.36
# 11342  ['B00JH2B182', 'B00JH29K6M', 'B00KNUC564', 'B0...  27.50
# 11343  ['B00ELN94GS', 'B00EP2P3ME', 'B00DQ2I0JC', 'B0...  19.99
# 11344  ['B00LORXVUE', 'B00LORY6IA', 'B00KK62714', 'B0...  36.00
# 11345  ['B00LFPS0CY', 'B00CHMWAY8', 'B00LU1V3JK', 'B0...   9.97
#
#                               salesRank
# 0                     {'Beauty': 10486}
# 1                     {'Beauty': 52254}
# 2                     {'Beauty': 78916}
# 3                       {'Beauty': 764}
# 4                    {'Beauty': 142503}
# ...                                 ...
# 11341                 {'Beauty': 26198}
# 11342  {'Health & Personal Care': 3006}
# 11343                  {'Beauty': 7597}
# 11344                 {'Beauty': 58521}
# 11345                  {'Beauty': 1265}
#
# [11346 rows x 6 columns]

# %%
# Mean rating for each Product

product_rating = df.groupby('asin')['avg.rating'].mean()
product_rating.head()
# Out:
# asin
# 7806397051    2.50
# 9759091062    3.09
# 9788072216    5.00
# 9790790961    4.60
# 9790794231    4.50
# Name: avg.rating, dtype: float64

# %%
# Mean rating KDE distribution

ax = sns.kdeplot(product_rating, shade=True, color='grey')
plt.show()

# %% [markdown]
# We can notice a large spike in the mean rating at value 5. This is a valuable indicator that points to the skewness of the data. Hence we need to further analyse this issue.

# %%
#data tranforming
# Data frame with calculated fields and measures

unique_products_list = df.asin.unique()
data_model = pd.DataFrame({'Rating': product_rating[unique_products_list]})
data_model.head()
# Out:
#             Rating
# asin
# 7806397051    2.50
# 9759091062    3.09
# 9788072216    5.00
# 9790790961    4.60
# 9790794231    4.50

# %%
print("Data model shape (number of data points): %s" % str(data_model.shape))
# Out:
# Data model shape (number of data points): (11346, 1)

# %%
#Summarise Rating

print(data_model.Rating.describe())
# Out:
# count    11346.000000
# mean         4.163377
# std          0.770957
# min          1.000000
# 25%          3.800000
# 50%          4.330000
# 75%          4.750000
# max          5.000000
# Name: Rating, dtype: float64

# %%
# Normalization function to range 0 - 10

def normalize(values):
    mn = values.min()
    mx = values.max()
    return(10.0/(mx - mn) * (values - mx)+10)

# %%
data_model_norm = normalize(data_model)
data_model_norm.head()
# Out:
#             Rating
# asin
# 7806397051   3.750
# 9759091062   5.225
# 9788072216  10.000
# 9790790961   9.000
# 9790794231   8.750

# %%
#Setting up the model

# Recommend 20 similar items
engine = KNeighborsClassifier(n_neighbors=20)

# Training data points
data_points = data_model_norm[[ 'Rating']].values

#Training labels
labels = data_model_norm.index.values

print("Data points: ")
print(data_points)
print("Labels: ")
print(labels)

engine.fit(data_points, labels)
# Out:
# Data points:
# [[ 3.75 ]
#  [ 5.225]
#  [10.   ]
#  ...
#  [10.   ]
#  [ 9.5  ]
#  [10.   ]]
# Labels:
# ['7806397051' '9759091062' '9788072216' ... 'B00LCEROA2' 'B00LG63DOM'
#  'B00LLPT4HI']
# KNeighborsClassifier(n_neighbors=20)

# %%
# Enter product ID to get a list of 20 recommended items

# User entered value
product_id = '9759091062'

product_data = [data_model_norm.loc[product_id][['Rating']].values]

recommended_products = engine.kneighbors(X=product_data, n_neighbors=20, return_distance=False)

# List of product IDs form the indexes

products_list = []

for each in recommended_products:
    products_list.append(data_model_norm.iloc[each].index)

print("Recommended products: ")
print(products_list)
# Out:
# Recommended products:
# [Index(['B003EN4T2U', 'B006OHM542', '9759091062', 'B0034BUQ42', 'B005F5J5Z6',
#        'B00FF5B31U', 'B009T47YZ2', 'B0068Y6CA4', 'B009YVCSYM', 'B001CS6BIY',
#        'B0042WIHNY', 'B001KYNVLU', 'B002GCKVJA', 'B00GBL5GDS', 'B002MOBZSS',
#        'B004ZC13OG', 'B0027U1D5W', 'B0009V1YR8', 'B002KFOX38', 'B004INQ65S'],
#       dtype='object', name='asin')]

# %% [markdown]
# FLIPKART WEBSITE

# %%
df1=pd.read_csv("/content/drive/MyDrive/flipkart_com-ecommerce_sample.csv")

# %%
df1
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/alisha-solid-women-s-c...
# 4      http://www.flipkart.com/sicons-all-purpose-arn...
# ...                                                  ...
# 19995  http://www.flipkart.com/walldesign-small-vinyl...
# 19996  http://www.flipkart.com/wallmantra-large-vinyl...
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree               pid  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1      ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
# ...                                                  ...               ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7KFJAKSTDY9G
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE9F5URNQGJCGH
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7VAYDKQZEBSD
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE8YSVEPPCZ42Y
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price  \
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
#                                                    image  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#        is_FK_Advantage_product  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 19995                    False
# 19996                    False
# 19997                    False
# 19998                    False
# 19999                    False
#
#                                              description       product_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4      Specifications of Sicons All Purpose Arnica Do...  No rating available
# ...                                                  ...                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...  No rating available
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...  No rating available
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
#
#             overall_rating             brand  \
# 0      No rating available            Alisha
# 1      No rating available      FabHomeDecor
# 2      No rating available                AW
# 3      No rating available            Alisha
# 4      No rating available            Sicons
# ...                    ...               ...
# 19995  No rating available        WallDesign
# 19996  No rating available        Wallmantra
# 19997  No rating available  Elite Collection
# 19998  No rating available  Elite Collection
# 19999  No rating available  Elite Collection
#
#                                   product_specifications
# 0      {"product_specification"=>[{"key"=>"Number of ...
# 1      {"product_specification"=>[{"key"=>"Installati...
# 2      {"product_specification"=>[{"key"=>"Ideal For"...
# 3      {"product_specification"=>[{"key"=>"Number of ...
# 4      {"product_specification"=>[{"key"=>"Pet Type",...
# ...                                                  ...
# 19995  {"product_specification"=>[{"key"=>"Number of ...
# 19996  {"product_specification"=>[{"key"=>"Number of ...
# 19997  {"product_specification"=>[{"key"=>"Number of ...
# 19998  {"product_specification"=>[{"key"=>"Number of ...
# 19999  {"product_specification"=>[{"key"=>"Number of ...
#
# [20000 rows x 15 columns]

# %%
df1.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                 78
# discounted_price             78
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
df1.shape
# Out:
# (20000, 15)

# %%
print("Shape: %s" % str(df1.shape))
print("Column names: %s" % str(df1.columns))
# Out:
# Shape: (20000, 15)
# Column names: Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
# Unique Users and Products

print("Unique UserID count: %s" % str(df1.uniq_id.nunique()))
print("Unique ProductID count: %s" % str(df1.pid.nunique()))
# Out:
# Unique UserID count: 20000
# Unique ProductID count: 19998

# %%
# Rating frequency

sns.set(rc={'figure.figsize': (11.7, 8.27)})
sns.set_style('whitegrid')
ax = sns.countplot(x='product_rating', data=df1, palette=sns.color_palette('Greys'))
ax.set(xlabel='Rating', ylabel='Count')
plt.show()

# %%
#preprocessing
def clean_product_type(dataframe):
    document=list(dataframe['product_category_tree'])
    product_types=[re.findall(r'\"(.*?)\"', sentence) for sentence in document]
    product_types=[' '.join(listed_items) for listed_items in product_types]
    return(product_types)

# %%
def clean_categories(dataframe):
    document=list(dataframe['product_category_tree'].values)
    categories=[re.findall(r'name=(.*?)}',sentence) for sentence in document]
    categories=[' '.join(word) for word in categories]
    return(categories)

# %%
def special_characters_cleaning(document):
    sentences=[]
    for sentence in document:
        sentences.append(re.sub('[^a-zA-Z0-9\n\.]',' ',str(sentence)))
    return(sentences)

# %%
def lemmetize_document(document):
    sentences=[]
    for sentence in document:
        word=[wordnet_lemmatizer.lemmatize(word) for word in word_tokenize(sentence)]
        sentences.append(' '.join(words))
    return(sentences)

# %%
def categories_extraction(dataframe):
    categories=[word for item in dataframe['categories'] for word in item.split()]
    categories=list(set(categories))
    return(categories)

# %%
def save_categories(dataframe):
    pass

# %%
def pre_processing_document(document):
    document=special_characters_cleaning(document)
    document=lemmetize_document(document)
    document=[sentence.title() for sentence in document]
    return(document)

# %%
def extract_categories_from_description(document,categories):
    extracted_categories=[]
    for sentence in document:
        extracted_categories.append(' '.join(set(categories).intersection(set(word_tokenize(sentence)))))
        return(extracted_categories)

# %%
lemmetize= WordNetLemmatizer()
stemmer=PorterStemmer()

# %%
df1["products"]=clean_product_type(df1)

# %%
df1["categories"]=clean_categories(df1)

# %%
categories= list(set(df1['product_category_tree'].values))
categories= [item.split() for item in df1['product_category_tree']]
categories= [word.lower() for listed_item in categories for word in listed_item]
categories= list(set(categories))

# %%
df1
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/alisha-solid-women-s-c...
# 4      http://www.flipkart.com/sicons-all-purpose-arn...
# ...                                                  ...
# 19995  http://www.flipkart.com/walldesign-small-vinyl...
# 19996  http://www.flipkart.com/wallmantra-large-vinyl...
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree               pid  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1      ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
# ...                                                  ...               ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7KFJAKSTDY9G
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE9F5URNQGJCGH
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7VAYDKQZEBSD
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE8YSVEPPCZ42Y
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price  \
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
#                                                    image  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#        is_FK_Advantage_product  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 19995                    False
# 19996                    False
# 19997                    False
# 19998                    False
# 19999                    False
#
#                                              description       product_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4      Specifications of Sicons All Purpose Arnica Do...  No rating available
# ...                                                  ...                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...  No rating available
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...  No rating available
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
#
#             overall_rating             brand  \
# 0      No rating available            Alisha
# 1      No rating available      FabHomeDecor
# 2      No rating available                AW
# 3      No rating available            Alisha
# 4      No rating available            Sicons
# ...                    ...               ...
# 19995  No rating available        WallDesign
# 19996  No rating available        Wallmantra
# 19997  No rating available  Elite Collection
# 19998  No rating available  Elite Collection
# 19999  No rating available  Elite Collection
#
#                                   product_specifications  \
# 0      {"product_specification"=>[{"key"=>"Number of ...
# 1      {"product_specification"=>[{"key"=>"Installati...
# 2      {"product_specification"=>[{"key"=>"Ideal For"...
# 3      {"product_specification"=>[{"key"=>"Number of ...
# 4      {"product_specification"=>[{"key"=>"Pet Type",...
# ...                                                  ...
# 19995  {"product_specification"=>[{"key"=>"Number of ...
# 19996  {"product_specification"=>[{"key"=>"Number of ...
# 19997  {"product_specification"=>[{"key"=>"Number of ...
# 19998  {"product_specification"=>[{"key"=>"Number of ...
# 19999  {"product_specification"=>[{"key"=>"Number of ...
#
#                                                 products categories
# 0      Clothing >> Women's Clothing >> Lingerie, Slee...
# 1      Furniture >> Living Room Furniture >> Sofa Bed...
# 2      Footwear >> Women's Footwear >> Ballerinas >> ...
# 3      Clothing >> Women's Clothing >> Lingerie, Slee...
# 4      Pet Supplies >> Grooming >> Skin & Coat Care >...
# ...                                                  ...        ...
# 19995  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19996  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19997  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19998  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19999  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
#
# [20000 rows x 17 columns]

# %%
df1['detailed_description']= df1['products']+ df1['brand']+df1['product_name']

# %%
df1
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/alisha-solid-women-s-c...
# 4      http://www.flipkart.com/sicons-all-purpose-arn...
# ...                                                  ...
# 19995  http://www.flipkart.com/walldesign-small-vinyl...
# 19996  http://www.flipkart.com/wallmantra-large-vinyl...
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree               pid  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1      ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
# ...                                                  ...               ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7KFJAKSTDY9G
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE9F5URNQGJCGH
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7VAYDKQZEBSD
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE8YSVEPPCZ42Y
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price  \
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
#                                                    image  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#        is_FK_Advantage_product  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 19995                    False
# 19996                    False
# 19997                    False
# 19998                    False
# 19999                    False
#
#                                              description       product_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4      Specifications of Sicons All Purpose Arnica Do...  No rating available
# ...                                                  ...                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...  No rating available
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...  No rating available
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
#
#             overall_rating             brand  \
# 0      No rating available            Alisha
# 1      No rating available      FabHomeDecor
# 2      No rating available                AW
# 3      No rating available            Alisha
# 4      No rating available            Sicons
# ...                    ...               ...
# 19995  No rating available        WallDesign
# 19996  No rating available        Wallmantra
# 19997  No rating available  Elite Collection
# 19998  No rating available  Elite Collection
# 19999  No rating available  Elite Collection
#
#                                   product_specifications  \
# 0      {"product_specification"=>[{"key"=>"Number of ...
# 1      {"product_specification"=>[{"key"=>"Installati...
# 2      {"product_specification"=>[{"key"=>"Ideal For"...
# 3      {"product_specification"=>[{"key"=>"Number of ...
# 4      {"product_specification"=>[{"key"=>"Pet Type",...
# ...                                                  ...
# 19995  {"product_specification"=>[{"key"=>"Number of ...
# 19996  {"product_specification"=>[{"key"=>"Number of ...
# 19997  {"product_specification"=>[{"key"=>"Number of ...
# 19998  {"product_specification"=>[{"key"=>"Number of ...
# 19999  {"product_specification"=>[{"key"=>"Number of ...
#
#                                                 products categories  \
# 0      Clothing >> Women's Clothing >> Lingerie, Slee...
# 1      Furniture >> Living Room Furniture >> Sofa Bed...
# 2      Footwear >> Women's Footwear >> Ballerinas >> ...
# 3      Clothing >> Women's Clothing >> Lingerie, Slee...
# 4      Pet Supplies >> Grooming >> Skin & Coat Care >...
# ...                                                  ...        ...
# 19995  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19996  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19997  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19998  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19999  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
#
#                                     detailed_description
# 0      Clothing >> Women's Clothing >> Lingerie, Slee...
# 1      Furniture >> Living Room Furniture >> Sofa Bed...
# 2      Footwear >> Women's Footwear >> Ballerinas >> ...
# 3      Clothing >> Women's Clothing >> Lingerie, Slee...
# 4      Pet Supplies >> Grooming >> Skin & Coat Care >...
# ...                                                  ...
# 19995  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19996  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19997  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19998  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
# 19999  Baby Care >> Baby & Kids Gifts >> Stickers >> ...
#
# [20000 rows x 18 columns]

# %%
document= list(df1['detailed_description'].values)
document= special_characters_cleaning(document)

# %%
tfidf= TfidfVectorizer(stop_words= 'english', vocabulary= categories)
data= tfidf.fit_transform(document)

# %%
from sklearn.neighbors import NearestNeighbors
nn= NearestNeighbors(algorithm= 'brute', n_neighbors= 20).fit(data)

# %%
text= df1[df1['brand']== "FabHomeDecor"]['detailed_description'].values
result = nn.kneighbors(tfidf.transform(text))
for col in tfidf.transform(text).nonzero()[1]:
    print(tfidf.get_feature_names()[col], ' - ', tfidf.transform(text)[0, col])
# Out:
# sofa  -  0.5494627319447266
# double  -  0.3362594739889644
# beds  -  0.23771412515246718
# fabric  -  0.3404245070225777
# furniture  -  0.31267075585498627
# living  -  0.1729910237070467
# futons  -  0.25687140760783667
# room  -  0.17792395156869212
# bed  -  0.28650919452707707
# fabhomedecor  -  0.25687140760783667
# finish  -  0.19805109200546914
# sofa  -  0.5494627319447266
# double  -  0.3362594739889644
# beds  -  0.23771412515246718
# fabric  -  0.3404245070225777
# furniture  -  0.31267075585498627
# living  -  0.1729910237070467
# futons  -  0.25687140760783667
# room  -  0.17792395156869212
# bed  -  0.28650919452707707
# fabhomedecor  -  0.25687140760783667
# finish  -  0.19805109200546914
# sofa  -  0.5494627319447266
# double  -  0.3362594739889644
# beds  -  0.23771412515246718
# fabric  -  0.3404245070225777
# furniture  -  0.31267075585498627
# living  -  0.1729910237070467
# futons  -  0.25687140760783667
# room  -  0.17792395156869212
# bed  -  0.28650919452707707
# fabhomedecor  -  0.25687140760783667
# finish  -  0.19805109200546914
# sofa  -  0.5494627319447266
# double  -  0.3362594739889644
# beds  -  0.23771412515246718
# fabric  -  0.3404245070225777
# furniture  -  0.31267075585498627
# living  -  0.1729910237070467
# futons  -  0.25687140760783667
# room  -  0.17792395156869212
# bed  -  0.28650919452707707
# fabhomedecor  -  0.25687140760783667
# finish  -  0.19805109200546914

# %% [markdown]
# BIGBASKET WEBSITE

# %%
df2=pd.read_csv("/content/drive/MyDrive/Big.csv")
df2
# Out:
#               pid                                            product  \
# 0      7806397051             Garlic Oil - Vegetarian Capsule 500 mg
# 1      9759091062                              Water Bottle - Orange
# 2      9788072216                     Brass Angle Deep - Plain, No.2
# 3      9790790961  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      9790794231                 Creme Soft Soap - For Hands & Body
# ...           ...                                                ...
# 11341  B00L5KTZ0K                          Roasted Peanut - Tandoori
# 11342  B00L6Q3BH6                        Light Hydration Body Lotion
# 11343  B00LCEROA2                                          Tru Apple
# 11344  B00LG63DOM                               ESPY EDP - For Women
# 11345  B00LLPT4HI                             Green Tea With Moringa
#
#                      category           sub_category             brand  \
# 0            Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1      Kitchen, Garden & Pets  Storage & Accessories        Mastercook
# 2        Cleaning & Household            Pooja Needs               Trm
# 3        Cleaning & Household   Bins & Bathroom Ware            Nakoda
# 4            Beauty & Hygiene       Bath & Hand Wash             Nivea
# ...                       ...                    ...               ...
# 11341  Snacks & Branded Foods       Snacks & Namkeen           Jabsons
# 11342        Beauty & Hygiene              Skin Care              Dove
# 11343   Bakery, Cakes & Dairy                  Dairy              Amul
# 11344        Beauty & Hygiene      Fragrances & Deos    Creation Lamis
# 11345               Beverages                    Tea         Sprig Tea
#
#        sale_price  market_price                      type  rating  \
# 0          220.00         220.0          Hair Oil & Serum     4.1
# 1          180.00         180.0    Water & Fridge Bottles     2.3
# 2          119.00         250.0           Lamp & Lamp Oil     3.4
# 3          149.00         176.0  Laundry, Storage Baskets     3.7
# 4          162.00         162.0      Bathing Bars & Soaps     4.4
# ...           ...           ...                       ...     ...
# 11341       70.00          70.0  Namkeen & Savoury Snacks     4.2
# 11342       96.00         100.0                 Body Care     4.8
# 11343       10.00          10.0      Flavoured, Soya Milk     4.1
# 11344     1234.05        1299.0             Eau De Parfum     NaN
# 11345      170.05         179.0                 Green Tea     3.6
#
#                                              description
# 0      This Product contains Garlic Oil that is known...
# 1      Each product is microwave safe (without lid), ...
# 2      A perfect gift for all occasions, be it your m...
# 3      Multipurpose container with an attractive desi...
# 4      Nivea Creme Soft Soap gives your skin the best...
# ...                                                  ...
# 11341  Jabsons roasted peanuts have a delicious tando...
# 11342  The new Dove Nourishing Body Care, Light Hydra...
# 11343  Amul Tru contains 30% fruit. The beverage perf...
# 11344  This Espy EDP women perfume arrives with the i...
# 11345  Nourish your path to wellness. This great tast...
#
# [11346 rows x 10 columns]

# %%
print("Shape: %s" % str(df2.shape))
print("Column names: %s" % str(df2.columns))
# Out:
# Shape: (11346, 10)
# Column names: Index(['pid', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# pid                0
# product            0
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          3570
# description       46
# dtype: int64

# %%
dff = df2.dropna(axis=0)
dff
# Out:
#               pid                                            product  \
# 0      7806397051             Garlic Oil - Vegetarian Capsule 500 mg
# 1      9759091062                              Water Bottle - Orange
# 2      9788072216                     Brass Angle Deep - Plain, No.2
# 3      9790790961  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      9790794231                 Creme Soft Soap - For Hands & Body
# ...           ...                                                ...
# 11339  B00L5BXG36  Bright Beauty Spot-less Glow Face Wash - With ...
# 11341  B00L5KTZ0K                          Roasted Peanut - Tandoori
# 11342  B00L6Q3BH6                        Light Hydration Body Lotion
# 11343  B00LCEROA2                                          Tru Apple
# 11345  B00LLPT4HI                             Green Tea With Moringa
#
#                      category           sub_category             brand  \
# 0            Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1      Kitchen, Garden & Pets  Storage & Accessories        Mastercook
# 2        Cleaning & Household            Pooja Needs               Trm
# 3        Cleaning & Household   Bins & Bathroom Ware            Nakoda
# 4            Beauty & Hygiene       Bath & Hand Wash             Nivea
# ...                       ...                    ...               ...
# 11339        Beauty & Hygiene              Skin Care             Ponds
# 11341  Snacks & Branded Foods       Snacks & Namkeen           Jabsons
# 11342        Beauty & Hygiene              Skin Care              Dove
# 11343   Bakery, Cakes & Dairy                  Dairy              Amul
# 11345               Beverages                    Tea         Sprig Tea
#
#        sale_price  market_price                      type  rating  \
# 0          220.00         220.0          Hair Oil & Serum     4.1
# 1          180.00         180.0    Water & Fridge Bottles     2.3
# 2          119.00         250.0           Lamp & Lamp Oil     3.4
# 3          149.00         176.0  Laundry, Storage Baskets     3.7
# 4          162.00         162.0      Bathing Bars & Soaps     4.4
# ...           ...           ...                       ...     ...
# 11339       78.72          82.0                 Face Care     4.2
# 11341       70.00          70.0  Namkeen & Savoury Snacks     4.2
# 11342       96.00         100.0                 Body Care     4.8
# 11343       10.00          10.0      Flavoured, Soya Milk     4.1
# 11345      170.05         179.0                 Green Tea     3.6
#
#                                              description
# 0      This Product contains Garlic Oil that is known...
# 1      Each product is microwave safe (without lid), ...
# 2      A perfect gift for all occasions, be it your m...
# 3      Multipurpose container with an attractive desi...
# 4      Nivea Creme Soft Soap gives your skin the best...
# ...                                                  ...
# 11339  Is your true brightness lost or hidden? Over t...
# 11341  Jabsons roasted peanuts have a delicious tando...
# 11342  The new Dove Nourishing Body Care, Light Hydra...
# 11343  Amul Tru contains 30% fruit. The beverage perf...
# 11345  Nourish your path to wellness. This great tast...
#
# [7738 rows x 10 columns]

# %%
dff.shape
# Out:
# (7738, 10)

# %%
dff.isnull().sum()
# Out:
# pid             0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
# Rating frequency

sns.set(rc={'figure.figsize': (11.7, 8.27)})
sns.set_style('whitegrid')
ax = sns.countplot(x='rating', data=dff, palette=sns.color_palette('Greys'))
ax.set(xlabel='Rating', ylabel='Count')
plt.show()

# %%
dff= dff.dropna()
dff=dff.drop(labels='category', axis=1)
dff=dff.drop(labels='product', axis=1)
dff=dff.drop(labels='sub_category', axis=1)
dff=dff.drop(labels='description', axis=1)

# %%
dff=dff.drop(labels='brand', axis=1)
dff=dff.drop(labels='type', axis=1)
dff = dff.drop(labels='market_price', axis=1)
dff
# Out:
#               pid  sale_price  rating
# 0      7806397051      220.00     4.1
# 1      9759091062      180.00     2.3
# 2      9788072216      119.00     3.4
# 3      9790790961      149.00     3.7
# 4      9790794231      162.00     4.4
# ...           ...         ...     ...
# 11339  B00L5BXG36       78.72     4.2
# 11341  B00L5KTZ0K       70.00     4.2
# 11342  B00L6Q3BH6       96.00     4.8
# 11343  B00LCEROA2       10.00     4.1
# 11345  B00LLPT4HI      170.05     3.6
#
# [7738 rows x 3 columns]

# %%
# Mean rating for each Product
product_rating = dff.groupby('pid')['rating'].mean()
product_rating.head()
# Out:
# pid
# 7806397051    4.1
# 9759091062    2.3
# 9788072216    3.4
# 9790790961    3.7
# 9790794231    4.4
# Name: rating, dtype: float64

# %%
# Mean rating KDE distribution
ax = sns.kdeplot(product_rating, shade=True, color='grey')
plt.show()

# %%
#data tranforming
# Data frame with calculated fields and measures
unique_products_list = dff.pid.unique()
data_model = pd.DataFrame({'rating':product_rating[unique_products_list]})
data_model.tail()
# Out:
#             rating
# pid
# B00L5BXG36     4.2
# B00L5KTZ0K     4.2
# B00L6Q3BH6     4.8
# B00LCEROA2     4.1
# B00LLPT4HI     3.6

# %%
print("Data model shape (number of data points): %s" %str(data_model.shape))
# Out:
# Data model shape (number of data points): (7738, 1)

# %%
#Summarise Rating
print(data_model.rating.describe())
# Out:
# count    7738.000000
# mean        3.940812
# std         0.740746
# min         1.000000
# 25%         3.700000
# 50%         4.100000
# 75%         4.300000
# max         5.000000
# Name: rating, dtype: float64

# %%
data_model_norm1= normalize(data_model)
data_model_norm1.tail()
# Out:
#             rating
# pid
# B00L5BXG36    8.00
# B00L5KTZ0K    8.00
# B00L6Q3BH6    9.50
# B00LCEROA2    7.75
# B00LLPT4HI    6.50

# %%
#Setting up the model
# Recommend 20 similar items
engine = KNeighborsClassifier(n_neighbors=20)
# Training data points
data_points1 = data_model_norm1[[ 'rating']].values
#Training labels
labels1 = data_model_norm1.index.values
print("Data points: ")
print(data_points1)
print("Labels: ")
print(labels1)
engine.fit(data_points1, labels1)
# Out:
# Data points:
# [[7.75]
#  [3.25]
#  [6.  ]
#  ...
#  [9.5 ]
#  [7.75]
#  [6.5 ]]
# Labels:
# ['7806397051' '9759091062' '9788072216' ... 'B00L6Q3BH6' 'B00LCEROA2'
#  'B00LLPT4HI']
# KNeighborsClassifier(n_neighbors=20)

# %%
# Enter product ID to get a list of 20 recommended items User entered value
pid = 'B00L6Q3BH6'
product_data = [data_model_norm1.loc[pid][['rating']].values]
recommended_products = engine.kneighbors(X=product_data,n_neighbors=20, return_distance=False)
# List of product IDs form the indexes
products_list = []
for each in recommended_products:
  if (products_list.append(data_model_norm1.iloc[0].index)):
       print("Recommended products: ")
       print(products_list)
  else :
       print("NO PRODUCTS SIMILAR TO THIS PID")
# Out:
# NO PRODUCTS SIMILAR TO THIS PID
